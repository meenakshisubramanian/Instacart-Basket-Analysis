# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge=pd.read_pickle(r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\02. Data\Prepared Data\orders_products_merged_derived.pkl')

# %%
# Creating subset for the latest dataframe

# %%
ords_prods_merge_sub=ords_prods_merge[:1000000]

# %% [markdown]
# Aggregating order_number based on department_id for the entire dataframe

# %%
ords_prods_merge_sub.groupby(['department_id']).agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# # Grouping min, max and mean of order number based on department_id for the entire dataframe not the above subset

# %%
ords_prods_merge.groupby('department_id').agg({'order_number':[ 'mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# As seen from the above result there are 21 deaprtments compared to lesser departments for the subset above.

# %%
ords_prods_merge['max_order']=ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\dsubr\AppData\Local\Temp\ipykernel_2024\2690353080.py:1: FutureWarning: The provided callable <function max at 0x000001E9785DA020> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order']=ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %% [markdown]
# # Transforming max value of order number from np library therby creating a new column max_order based on user_id- column max_order created

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# # Assigning loyalty_flag for customers
# Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking frequency for the same

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Checking new column loyalty_flag in dataframe

# %%
ords_prods_merge[['user_id','loyalty_flag','order_number','max_order']].head(20)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0         1      New customer             1         10
# 1         1      New customer             2         10
# 2         1      New customer             3         10
# 3         1      New customer             4         10
# 4         1      New customer             5         10
# 5         1      New customer             6         10
# 6         1      New customer             7         10
# 7         1      New customer             8         10
# 8         1      New customer             9         10
# 9         1      New customer            10         10
# 10       15  Regular customer            15         22
# 11       15  Regular customer            17         22
# 12       15  Regular customer            18         22
# 13       15  Regular customer            21         22
# 14       15  Regular customer            22         22
# 15       19      New customer             2          9
# ...

# %%
# For the new column loyalty_flag check the min, mean and max based on prices paid (purchased) by the customers

# %% [markdown]
# The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.groupby(['loyalty_flag']).agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386335  1.0  99999.0
# New customer      13.294669  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# finding spender -creating spending flag

# %%
ords_prods_merge['spending_average']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\dsubr\AppData\Local\Temp\ipykernel_2024\3146057263.py:1: FutureWarning: The provided callable <function mean at 0x000001E9785DAA20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['spending_average']=ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['spending_average']<10,'spender_flag']='Low_spender'

ords_prods_merge.loc[ords_prods_merge['spending_average']>= 10, 'spender_flag'] = 'High_spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     31770614
# High_spender      634245
# Name: count, dtype: int64

# %%
pd.options.display.max_rows=None

# %%
ords_prods_merge[['user_id','spending_average','spender_flag','prices']].head(100)
# Out:
#     user_id  spending_average  spender_flag  prices
# 0         1          6.367797   Low_spender     9.0
# 1         1          6.367797   Low_spender     9.0
# 2         1          6.367797   Low_spender     9.0
# 3         1          6.367797   Low_spender     9.0
# 4         1          6.367797   Low_spender     9.0
# 5         1          6.367797   Low_spender     9.0
# 6         1          6.367797   Low_spender     9.0
# 7         1          6.367797   Low_spender     9.0
# 8         1          6.367797   Low_spender     9.0
# 9         1          6.367797   Low_spender     9.0
# 10       15          3.980556   Low_spender     9.0
# 11       15          3.980556   Low_spender     9.0
# 12       15          3.980556   Low_spender     9.0
# 13       15          3.980556   Low_spender     9.0
# 14       15          3.980556   Low_spender     9.0
# 15       19          8.372059   Low_spender     9.0
# 16       19          8.372059   Low_spender     9.0
# ...

# %% [markdown]
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
# Ensure your notebook is clean and structured and that

# %%
# Creating customer frequency column

# %%
ords_prods_merge['customer_frequency']=ords_prods_merge.groupby(['user_id'])['days_since_previous_order'].transform(np.mean)
# Out:
# C:\Users\dsubr\AppData\Local\Temp\ipykernel_2024\3552267135.py:1: FutureWarning: The provided callable <function mean at 0x000001E9785DAA20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['customer_frequency']=ords_prods_merge.groupby(['user_id'])['days_since_previous_order'].transform(np.mean)

# %%
checking condition for flag value of customer frequency

# %%
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] > 20, 'frequency_flag'] = 'Non_frequent_customer'

ords_prods_merge.loc[(ords_prods_merge['customer_frequency']>10) & (ords_prods_merge['customer_frequency']<=20),'frequency_flag'] = 'Regular customer'

ords_prods_merge.loc[ords_prods_merge['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# frequency_flag
# Frequent Customer        16468582
# Regular customer         12521159
# Non_frequent_customer     3415113
# NaN                             5
# Name: count, dtype: int64

# %%
Nan are new customers purchased may be once .

# %%
Checking the newely added column customer_frequency and frequency_flag values

# %%
ords_prods_merge[['user_id','days_since_previous_order','customer_frequency','frequency_flag']].head(100)
# Out:
#     user_id  days_since_previous_order  customer_frequency  \
# 0         1                        NaN           20.259260
# 1         1                       15.0           20.259260
# 2         1                       21.0           20.259260
# 3         1                       29.0           20.259260
# 4         1                       28.0           20.259260
# 5         1                       19.0           20.259260
# 6         1                       20.0           20.259260
# 7         1                       14.0           20.259260
# 8         1                        0.0           20.259260
# 9         1                       30.0           20.259260
# 10       15                        7.0           11.029411
# 11       15                        8.0           11.029411
# 12       15                        7.0           11.029411
# 13       15                        7.0           11.029411
# 14       15                       14.0           11.029411
# ...

# %% [markdown]
# Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\02. Data\Prepared Data\orders_products_aggregated.pkl')

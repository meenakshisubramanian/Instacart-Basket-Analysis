# %%
#import libaries
import pandas as pd
import numpy as np
import os

# %%
df_prods=pd.read_csv(r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\02. Data\Prepared Data\products_cleaned.csv',index_col=False)

# %%
orders_products_combined=pd.read_pickle(r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\03.Scripts\orders_products_combined.pkl')

# %%
pd.merge(orders_products_combined,df_prods, on = ['product_id'], indicator='True')
# Out:
#           order_id  user_id  order_number  orders_day_of_week  order_hour  \
# 0          2539329        1             1                   2           8
# 1          2539329        1             1                   2           8
# 2          2539329        1             1                   2           8
# 3          2539329        1             1                   2           8
# 4          2539329        1             1                   2           8
# ...            ...      ...           ...                 ...         ...
# 32434207   2977660   206209            13                   1          12
# 32434208   2977660   206209            13                   1          12
# 32434209   2977660   206209            13                   1          12
# 32434210   2977660   206209            13                   1          12
# 32434211   2977660   206209            13                   1          12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'true')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'true')
#
# File E:\Anaconda\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
# ...

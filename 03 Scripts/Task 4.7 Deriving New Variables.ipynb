# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\02. Data\Prepared Data\orders_products_merged_downcast.pkl')

# %%
df=ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range']=df.apply(price_label,axis=1)
# Out:
# C:\Users\dsubr\AppData\Local\Temp\ipykernel_2176\3001267412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label,axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.800000190734863

# %%
 df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\dsubr\AppData\Local\Temp\ipykernel_2176\3104298320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000000 entries, 0 to 999999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   order_id                   1000000 non-null  int32
#  1   user_id                    1000000 non-null  int32
#  2   order_number               1000000 non-null  int8
#  3   orders_day_of_week         1000000 non-null  int8
#  4   order_hour_of_day          1000000 non-null  int8
#  5   days_since_previous_order  939915 non-null   float32
#  6   product_id                 1000000 non-null  int32
#  7   add_to_cart_order          1000000 non-null  int16
#  8   reordered                  1000000 non-null  int8
#  9   Unnamed: 0                 1000000 non-null  int32
#  10  product_name               1000000 non-null  object
#  11  aisle_id                   1000000 non-null  int16
#  12  department_id              1000000 non-null  int8
# ...

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price_range_loc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 ords_prods_merge['price_range_loc'].value_counts(dropna=False)
#
# ...

# %% [markdown]
# Busiest day of the week

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['Busiest Day']=result

# %%
ords_prods_merge['Busiest Day'].value_counts(dropna=False)
# Out:
# Busiest Day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
Busiest_days = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value == 1:
    Busiest_days.append("Busiest day")
  elif value == 4 or value == 3:
    Busiest_days.append("Slowest day")
  else:
    Busiest_days.append("Regularly busy day")

# %%
Busiest_days
# Out:
# ['Regularly busy day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Regularly busy day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Slowest day',
#  'Busiest day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Busiest day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Busiest day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Slowest day',
#  'Regularly busy day',
#  'Slowest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy day',
#  'Slowest day',
#  'Slowest day',
#  'Regularly busy day',
#  'Regularly busy day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy day',
# ...

# %% [markdown]
# Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
ords_prods_merge['Busiest Days']=Busiest_days

# %%
ords_prods_merge['Busiest Days'].value_counts(dropna=False)
# Out:
# Busiest Days
# Regularly busy day    12916111
# Busiest day           11864412
# Slowest day            7624336
# Name: count, dtype: int64

# %%
ords_prods_merge['orders_day_of_week'].max()
# Out:
# 6

# %% [markdown]
# When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %% [markdown]
# # Creating new column busiest_period_of_day

# %%
ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_previous_order  product_id  add_to_cart_order  reordered  \
# 0                        NaN         196                  1          0
# 1                       15.0         196                  1          1
# 2                       21.0         196                  1          1
# 3                       29.0         196                  1          1
# 4                       28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices     Busiest Day  \
# ...

# %%
busiest_period_of_day = []
for value in ords_prods_merge["order_hour_of_day"]:
  if value == 0 or value <=10:
   busiest_period_of_day.append("Fewest orders")
  elif value >= 8  or value <= 14:
   busiest_period_of_day.append("Average orders")
  else:
   busiest_period_of_day.append("Most orders")

# %%
ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# Most orders can be classified as 10,11,14,15,13,12,16 and 9, Fewest orders as 0,2,3,4,5,7 and the rest as Average orders all the remaining order_hour_of_day

# %%
busiest_period_of_day = []

for value in ords_prods_merge["order_hour_of_day"]:
  if value in [10,1,14,15,12,16,9]:
   busiest_period_of_day.append("Most orders")
  elif value in[0,2,3,4,5,7]:
      busiest_period_of_day.append("Fewest orders")
  else:
   busiest_period_of_day.append("Average orders")

# %%
busiest_period_of_day
# Out:
# ['Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
ords_prods_merge['busiest_period_of_day']=busiest_period_of_day

# %% [markdown]
# Print the frequency for this new column.

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       15836677
# Average orders    15196500
# Fewest orders      1371682
# Name: count, dtype: int64

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   order_id                   int32
#  1   user_id                    int32
#  2   order_number               int8
#  3   orders_day_of_week         int8
#  4   order_hour_of_day          int8
#  5   days_since_previous_order  float32
#  6   product_id                 int32
#  7   add_to_cart_order          int16
#  8   reordered                  int8
#  9   Unnamed: 0                 int32
#  10  product_name               object
#  11  aisle_id                   int16
#  12  department_id              int8
#  13  prices                     float32
#  14  Busiest Day                object
#  15  Busiest Days               object
#  16  busiest_period_of_day      object
# dtypes: float32(2), int16(2), int32(4), int8(5), object(4)
# memory usage: 2.2+ GB

# %% [markdown]
# Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
path=r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\02. Data\Prepared Data\orders_products_merged_downcast.pkl'

# %%
path
# Out:
# 'C:\\Users\\dsubr\\Downloads\\11-04-2025 Instacart Basket Analysis\\02. Data\\Prepared Data\\orders_products_merged_downcast.pkl'

# %%
ords_prods_merge.to_pickle(r'C:\Users\dsubr\Downloads\11-04-2025 Instacart Basket Analysis\02. Data\Prepared Data\orders_products_merged_derived.pkl')
